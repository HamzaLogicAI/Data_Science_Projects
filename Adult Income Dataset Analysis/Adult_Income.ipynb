# %% [markdown]
# ## Importing the Required Libraries and the Dataset

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('Adult_Income.csv')

# %% [markdown]
# ### Display the Top 3 Rows of the Dataset

# %%
data.head(3)
# Out:
#                                                                                                                                                                       <<<<<<< HEAD
# age workclass fnlwgt education educational-num marital-status     occupation        relationship race  gender capital-gain capital-loss hours-per-week native-country       income
# 25  Private   226802 11th      7               Never-married      Machine-op-inspct Own-child    Black Male   0            0            40             United-States         <=50K
# 38  Private   89814  HS-grad   9               Married-civ-spouse Farming-fishing   Husband      White Male   0            0            50             United-States         <=50K

# %% [markdown]
# ### Display the Last 3 Rows of the Dataset

# %%
data.tail(3)
# Out:
#                                                                                                                                                                       <<<<<<< HEAD
# 22                                         Private      201490.0 HS-grad 9.0 Never-married      Adm-clerical    Own-child White Male   0.0     0.0 20.0 United-States        <=50K
# >>>>>>> f1e6323 (Your commit message here) NaN          NaN      NaN     NaN NaN                NaN             NaN       NaN   NaN    NaN     NaN NaN  NaN                    NaN
# 52                                         Self-emp-inc 287927.0 HS-grad 9.0 Married-civ-spouse Exec-managerial Wife      White Female 15024.0 0.0 40.0 United-States         >50K

# %% [markdown]
# ### Describing the Terms Used

# %% [markdown]
# #### fnlwgt:
# This column represents the final weight.
# #### educational-num:
# This column likely represents the educational number or educational level encoded as a numerical value.This numerical scale might correspond to different levels of education such as 1 for primary education, 2 for secondary education, and so on.
# #### Capital gain:
# refers to the profit earned from the sale of assets or investments such as stocks, bonds, real estate, etc. It's the difference between the sale price and the purchase price of the asset.
# #### Capital Loss:
# Similar to capital gain, this column represents the amount of capital loss reported by an individual.

# %% [markdown]
# ### Finding the Shape of the Dataset

# %%
print("No. of the Rows:",data.shape[0])
print("No. of the Columns:", data.shape[1])
# Out:
# No. of the Rows: 97687
# No. of the Columns: 1

# %% [markdown]
# ### Getting all the Info of the Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 97687 entries, ('age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country') to ('52', 'Self-emp-inc', 287927.0, 'HS-grad', 9.0, 'Married-civ-spouse', 'Exec-managerial', 'Wife', 'White', 'Female', 15024.0, 0.0, 40.0, 'United-States')
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   <<<<<<< HEAD  97685 non-null  object
# dtypes: object(1)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Getting the Overall Statistics of the Dataset

# %%
data.describe()
# Out:
#        <<<<<<< HEAD
# count         97685
# unique            3
# top           <=50K
# freq          74310

# %% [markdown]
# ### Fetch the Random Samples from the Dataset

# %%
data.sample(frac=0.5,random_state=100)
# Out:
#                                                                                                                                                        <<<<<<< HEAD
# 52 Private          29658    HS-grad      9    Married-civ-spouse Adm-clerical   Husband       White              Male   0      0   40   United-States        <=50K
# 23 Private          161478   Some-college 10   Never-married      Sales          Own-child     Asian-Pac-Islander Female 0      0   40   United-States        <=50K
# 58 Private          125317   Doctorate    16   Married-civ-spouse Prof-specialty Husband       White              Male   0      0   60   United-States         >50K
# 27 Private          239130   Prof-school  15   Never-married      Prof-specialty Own-child     White              Male   0      0   40   United-States        <=50K
# 66 Self-emp-not-inc 174995.0 Assoc-acdm   12.0 Married-civ-spouse Craft-repair   Husband       White              Male   2290.0 0.0 30.0 Hungary              <=50K
# ...                                                                                                                                                             ...
# 60 ?                251572   HS-grad      9    Widowed            ?              Not-in-family White              Male   0      0   35   Poland               <=50K
# 25 Private          97789.0  Bachelors    13.0 Never-married      Sales          Own-child     White              Male   0.0    0.0 50.0 United-States        <=50K
# 44 Private          219288.0 7th-8th      4.0  Married-civ-spouse Craft-repair   Husband       White              Male   0.0    0.0 35.0 United-States        <=50K
# 65 Private          123965   Bachelors    13   Widowed            Other-service  Not-in-family White              Female 0      0   40   United-States        <=50K
# 39 Private          30269.0  Assoc-voc    11.0 Divorced           Sales          Unmarried     White              Female 0.0    0.0 40.0 United-States        <=50K
#
# [48844 rows x 1 columns]

# %% [markdown]
# ### Checking the Null Values in the Dataset

# %%
data.isnull().sum()
# Out:
# <<<<<<< HEAD    2
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: ylabel='None-None-None-None-None-None-None-None-None-None-None-None-None-None'>

# %%
data.isin(["?"]).sum()
# Out:
# <<<<<<< HEAD    0
# dtype: int64

# %%
data["workclass"] = data["workclass"].replace("?", np.nan)
data["occupation"] = data["occupation"].replace("?", np.nan)
data["native-country"] = data["native-country"].replace("?", np.nan)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'workclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data["workclass"] = data["workclass"].replace("?", np.nan)
#       2 data["occupation"] = data["occupation"].replace("?", np.nan)
#       3 data["native-country"] = data["native-country"].replace("?", np.nan)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'workclass'

# %%
data.isnull().sum()

# %%
sns.heatmap(data.isnull())

# %%
per_missing=data.isnull().sum()*100/len(data)

# %%
per_missing

# %% [markdown]
# ### Dropping the Missing Values

# %%
data.dropna(how='any',inplace=True)

# %%
data.isnull().sum()

# %% [markdown]
# ### Check for the Duplicates and Drop them

# %%
data.duplicated().any()

# %% [markdown]
# ### Dropping the Unnecessary Columns

# %%
data=data.drop(["fnlwgt","educational-num","capital-gain","capital-loss"],axis=1)

# %%
data.head()

# %% [markdown]
# # ---Univariate Analysis---

# %% [markdown]
# ### Making the Categories of "education" Column

# %%
def clean_education(x):
    if x=="Bachelors": 
        return "Bachelor's Degree"
    if x=="Assoc-voc":
        return "Bachelor's Degree"
    if x=="Masters": 
        return "Master's Degree" 
    if x=="Prof-school":
         return "Master's Degree"
    if x=="Doctorate":
        return "Doctorate Degree"
    else:
        return "Less than Bachelor's"

# %%
data["education"]=data["education"].apply(clean_education)

# %%
data["education"].unique()

# %% [markdown]
# ### What is the Distribution of the Age Column

# %%
data["age"].describe()

# %%
data["age"].hist()

# %% [markdown]
# ### Find the Total No. of the People having the Age between 17 to 48

# %%
sum((data["age"]>=17)&(data["age"]<=48))

# %%
sum(data["age"].between(17,48))

# %% [markdown]
# ### What is the Distribution of the Workclass Column

# %%
data["workclass"].describe()

# %%
plt.figure(figsize=(8,6))
data["workclass"].hist()

# %% [markdown]
# ### How many people have the Bachelors or Masters Degree

# %%
filter1=data["education"]=='Bachelors'
filter2=data["education"]=='Masters'

# %%
len(data[filter1|filter2])

# %% [markdown]
# ### Capitalizing the Column Names

# %%
data.columns

# %%
data.rename(columns={"age": "Age","workclass":"Workclass","education":"Education","marital-status":"Marital-status","occupation":"Occupation","relationship":"Relationship","race":"Race","gender":"Gender","hours-per-week":"Hours-per-week","native-country":"Native-country","income":"Income"}, inplace=True)

# %% [markdown]
# # ---Bivariate Analysis---

# %% [markdown]
# ### Plot the Graph between the 'Salary' & 'Age'

# %%
sns.barplot(x="Income",y="Age",data=data)

# %% [markdown]
# ### Convert Categorical Values to the Numerical Values for 'income' Column

# %%
data.columns

# %%
def income_data(income):
    if income=="<=50K":
        return 0
    else:
        return 1
data["Encoded_Salary"]=data["Income"].apply(income_data)

# %%
data.head()

# %% [markdown]
# ### Convert the Workclass Column datatype to Categorical datatype

# %%
data["Workclass"].astype("category")

# %%
data.dtypes

# %%
data2=data.to_csv("Filtered.csv",index=None)
